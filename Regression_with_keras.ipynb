# %% [markdown]
# # Use case: Build an ANN model that predicts the Power Energy for Powerplant based data. Independent features: sensor readings related to powerplant machines

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv(r'https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlant.csv')
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# AT: Atmospheric Temperature V: Vaccum AP: Atmospheric Pressure RH: Relative Humidity PE: Power Energy

# %% [markdown]
# # Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df=df.drop_duplicates()

# %% [markdown]
# # Separate data inti X and Y features

# %%
X = df.drop(columns=['PE'])
Y = df[['PE']]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# # Data preprocessing and Data cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),StandardScaler()).set_output(transform='pandas')

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.85,random_state=21)

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (8097, 4) (1430, 4) (8097, 1) (1430, 1)

# %% [markdown]
# # Artificial Neural Network Model Building

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
xtrain.shape
# Out:
# (8097, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
model = Sequential()

# Add the input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the hidden layer1
model.add(Dense(units=8,activation='relu'))

# Add the hidden layer2
model.add(Dense(units=4,activation='relu'))

# Add the output layer
model.add(Dense(units=1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae'])

# %%
nn = model.fit(xtrain,ytrain,validation_split=0.2,epochs=40)
# Out:
# Epoch 1/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 205719.9375 - mae: 453.2540 - val_loss: 201695.0938 - val_mae: 448.8123
# Epoch 2/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 197520.4531 - mae: 444.1293 - val_loss: 180482.4844 - val_mae: 424.5968
# Epoch 3/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 170240.9375 - mae: 412.0931 - val_loss: 134186.2500 - val_mae: 365.1139
# Epoch 4/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120218.8750 - mae: 344.0007 - val_loss: 77807.0938 - val_mae: 271.4926
# Epoch 5/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66580.1875 - mae: 246.0162 - val_loss: 38651.5586 - val_mae: 173.9254
# Epoch 6/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34267.8359 - mae: 161.2317 - val_loss: 23506.4980 - val_mae: 130.5200
# Epoch 7/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 22499.1738 - mae: 127.5581 - val_loss: 18364.6523 - val_mae: 115.6723
# Epoch 8/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18162.5078 - mae: 114.6479 - val_loss: 14893.3311 - val_mae: 103.9173
# Epoch 9/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14500.5645 - mae: 101.9495 - val_loss: 11594.0986 - val_mae: 91.2818
# Epoch 10/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11113.7705 - mae: 89.2089 - val_loss: 8550.4180 - val_mae: 78.0708
# Epoch 11/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8069.9395 - mae: 75.9828 - val_loss: 5914.8555 - val_mae: 64.4758
# Epoch 12/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5541.0757 - mae: 62.3422 - val_loss: 3913.4604 - val_mae: 52.0069
# Epoch 13/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3541.6758 - mae: 49.2090 - val_loss: 2521.1772 - val_mae: 41.3583
# Epoch 14/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2320.4897 - mae: 39.0768 - val_loss: 1639.6567 - val_mae: 32.7164
# Epoch 15/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1476.2659 - mae: 30.3994 - val_loss: 1124.2715 - val_mae: 26.5840
# Epoch 16/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1062.2163 - mae: 25.3154 - val_loss: 837.2946 - val_mae: 22.6323
# Epoch 17/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 817.5631 - mae: 22.1558 - val_loss: 674.8593 - val_mae: 20.5618
# Epoch 18/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 701.4234 - mae: 20.7916 - val_loss: 569.2563 - val_mae: 19.0749
# Epoch 19/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 583.6625 - mae: 19.1530 - val_loss: 489.8663 - val_mae: 17.7857
# Epoch 20/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 494.1337 - mae: 17.7012 - val_loss: 419.2474 - val_mae: 16.4770
# Epoch 21/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 425.7673 - mae: 16.5225 - val_loss: 355.7370 - val_mae: 15.1767
# Epoch 22/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 374.3271 - mae: 15.5859 - val_loss: 300.4020 - val_mae: 13.8505
# Epoch 23/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 319.2853 - mae: 14.2439 - val_loss: 252.1830 - val_mae: 12.6994
# Epoch 24/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 268.7674 - mae: 13.0414 - val_loss: 213.7893 - val_mae: 11.6537
# Epoch 25/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 230.8194 - mae: 12.0368 - val_loss: 185.3526 - val_mae: 10.8607
# Epoch 26/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 211.0480 - mae: 11.3847 - val_loss: 164.3639 - val_mae: 10.2407
# Epoch 27/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 181.4507 - mae: 10.5536 - val_loss: 148.6300 - val_mae: 9.7588
# Epoch 28/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 156.6515 - mae: 9.9492 - val_loss: 135.8407 - val_mae: 9.3567
# Epoch 29/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 146.6977 - mae: 9.5999 - val_loss: 124.1520 - val_mae: 8.9494
# Epoch 30/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 139.3388 - mae: 9.3352 - val_loss: 115.3781 - val_mae: 8.6155
# Epoch 31/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 122.5112 - mae: 8.7964 - val_loss: 107.7387 - val_mae: 8.3253
# Epoch 32/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115.9732 - mae: 8.5728 - val_loss: 99.4851 - val_mae: 7.9772
# Epoch 33/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111.7930 - mae: 8.3258 - val_loss: 92.7850 - val_mae: 7.7094
# Epoch 34/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.1996 - mae: 7.9075 - val_loss: 86.8800 - val_mae: 7.4481
# Epoch 35/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96.4188 - mae: 7.8080 - val_loss: 81.1871 - val_mae: 7.2112
# Epoch 36/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92.1190 - mae: 7.5866 - val_loss: 75.8270 - val_mae: 6.9464
# Epoch 37/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.3237 - mae: 7.3312 - val_loss: 72.4942 - val_mae: 6.7795
# Epoch 38/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76.5400 - mae: 6.9925 - val_loss: 67.5551 - val_mae: 6.5534
# Epoch 39/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.9739 - mae: 6.9064 - val_loss: 64.0931 - val_mae: 6.3829
# Epoch 40/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 68.1723 - mae: 6.5850 - val_loss: 61.3177 - val_mae: 6.2477

# %%
# plot the learning curve
import matplotlib.pyplot as plt
plt.plot(nn.history['loss'],label='Training Loss')
plt.plot(nn.history['val_loss'],label='Validation Loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.title('Learning Curve')
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.2609 - mae: 6.4718
# [65.39493560791016, 6.422916412353516]

# %%
model.evaluate(xtest,ytest)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.4229 - mae: 6.3940
# [66.10619354248047, 6.55576229095459]

# %%
ypred_test =model.predict(xtest)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
ypred_train=model.predict(xtrain)
# Out:
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse1 = mean_squared_error(ytrain,ypred_train)
mae1 = mean_absolute_error(ytrain,ypred_train)
r21 = r2_score(ytrain,ypred_train)

print(f'Mean Squared Error:{mse1}')
print(f'Mean Absolute Error:{mae1}')
print(f'R2 Score:{r21}')
# Out:
# Mean Squared Error:65.39492797851562
# Mean Absolute Error:6.422916889190674
# R2 Score:0.7739614248275757

# %%
mse = mean_squared_error(ytest,ypred_test)
mae = mean_absolute_error(ytest,ypred_test)
r2 = r2_score(ytest,ypred_test)
print(f"Mean Squared Error:{mse}")
print(f"Mean Absolute Error:{mae}")
print(f"R2 Score:{r2}")
# Out:
# Mean Squared Error:66.106201171875
# Mean Absolute Error:6.555760860443115
# R2 Score:0.7764981985092163

# %% [markdown]
# # save the model

# %%
model.save('PEPredictions.keras')

# %% [markdown]
# # Load the model

# %%
from keras.models import load_model
m = load_model('/content/PEPredictions.keras')
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)

# %% [markdown]
# # Generate out of sample predictions

# %%
xnew = pd.read_csv(r'https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlantTest.csv')
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.717594 -0.220203 -2.211551 -1.118316
# 1  1.657948 -1.047911  6.373998  0.456299
# 2  1.120603  0.000000 -0.511275  0.000000

# %%
PE_preds = m.predict(xnew_pre)
PE_preds
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# array([[439.1817 ],
#        [445.72903],
#        [436.86288]], dtype=float32)

# %%
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew["PE predictions"] = PE_preds.round()

# %%
xnew
# Out:
#    AT     V      AP    RH  PE predictions
# 0  25  51.5  1000.1  57.0           439.0
# 1  32  41.0  1051.1  80.0           446.0
# 2  28   NaN  1010.2   NaN           437.0

# %%
xnew['PE predictions'] = xnew['PE predictions'].astype(int).round(2)

# %%
xnew
# Out:
#    AT     V      AP    RH  PE predictions
# 0  25  51.5  1000.1  57.0             439
# 1  32  41.0  1051.1  80.0             446
# 2  28   NaN  1010.2   NaN             437

# %%
xnew.to_csv("Prediction_Results_updated.csv",index=False)
